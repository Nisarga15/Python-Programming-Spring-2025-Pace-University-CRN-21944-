# %% [markdown]
# ##Assignment - 1
#
# **Answer the following questions, after completing answering please download the .ipynb or .py file and submit the file.**
# * Name : Nisarga Vishwamanjuswamy
# * Sesion :
# * CRN : 21944

# %% [markdown]
# Write a brief description of all the following Object Types. To write the answers in below cell by double clicking on it.

# %% [markdown]
# Double Click HERE to edit this markdown cell and write answers.
#
# Numbers: Numbers can be represented as integers, floating-point numbers, or complex numbers. Integers are whole numbers, floating-point numbers have a decimal point, and complex numbers have a real and imaginary part.
#
# Strings: Strings are sequences of characters, enclosed within either single quotes (''), double quotes ("") or triple quotes (''' ''' or """ """). They are used to represent text data and are immutable.
#
# Lists: Lists are ordered collections of items, which can be of any data type. They are mutable. Lists are defined using square brackets [ ] and elements are separated by commas.
#
# Tuples: Tuples are similar to lists but are immutables. They are defined using parentheses ( ) and elements are separated by commas.
#
# Dictionaries: Dictionaries are unordered collections of key-value pairs. Each key is unique and associated with a value. Dictionaries are mutable and are defined using curly braces { } with key-value pairs separated by colons ( : ), and pairs separated by commas.

# %% [markdown]
# ## Numbers

# %% [markdown]
# Answer these 3 questions type code to check your answer. In the below code cell.
#
#     What is the value of the expression 4 * (6 + 5)
#     44
#     What is the value of the expression 4 * 6 + 5
#     29
#     What is the value of the expression 4 + 6 * 5
#     34

# %%
a1 = 4 * (6 + 5)
print(a1)
a2 = 4 * 6 + 5
print(a2)
a3 = 4 + 6 * 5
print(a3)
# Out:
# 44
# 29
# 34

# %% [markdown]
# ## Strings

# %% [markdown]
# Given the string 'Python Programming', with the help of index get 'm'. Enter your code in the cell below:

# %%
s = 'Python Programming'
# Print out 'm' using indexing
a = s[13]
print(a)
# Out:
# m

# %% [markdown]
# Reverse the string 'Python Programming' using slicing:

# %%
s ='Python Programming'
# Reverse the string using slicing
a = s[::-1]
print(a)
# Out:
# gnimmargorP nohtyP

# %% [markdown]
# Given the string "Python Programming", give two methods of producing the letter 'i' using indexing.

# %%
s ='Python Programming'
# Print out the 'i'

# Method 1:
a = s[15]
print(a)
# Out:
# i

# %%
# Method 2:
a = s[-3]
print(a)
# Out:
# i

# %% [markdown]
# ## Lists

# %% [markdown]
# Build this list [0,0,0] two separate ways.

# %%
# Method 1:
l = [0,0,0]
print(l)
# Out:
# [0, 0, 0]

# %%
# Method 2:
l = [0] * 3
l
# Out:
# [0, 0, 0]

# %% [markdown]
# Reassign 'hello' in this nested list to say 'goodbye' instead:

# %%
list3 = [1,2,[3,4,'hello']]
list3[2][2] = 'goodbye'
list3
# Out:
# [1, 2, [3, 4, 'goodbye']]

# %% [markdown]
# Sort the list below:

# %%
list4 = [5,3,4,6,1]
l4 = sorted(list4)
l4
# Out:
# [1, 3, 4, 5, 6]

# %% [markdown]
# ## Dictionaries

# %% [markdown]
# Using keys and indexing, grab the 'Python' from the following dictionaries:

# %%
d = {'simple_key':'Python'}
# Grab 'Python'
d['simple_key']
# Out:
# 'Python'

# %%
d = {'k1':{'k2':'Programming'}}
# Grab 'Programming'
d['k1']['k2']
# Out:
# 'Programming'

# %%
# Getting a little tricker
d = {'k1':[{'nest_key':['this is CS632',['Python']]}]}

#Grab Python
d['k1'][0]['nest_key'][1]
# Out:
# ['Python']

# %%
# This will be hard and annoying!
d = {'k1':[1,2,{'k2':['this is tricky',{'tough':[1,2,['hello']]}]}]}
d['k1'][2]['k2'][1]['tough'][2]
# Out:
# ['hello']

# %% [markdown]
# Is sorting a dictionary possible? Why or why not?<br><br>
# No, sorting a dictionary directly is not possible because dictionaries are unordered collections where elements are stored and accessed by keys, not by their order of insertion. To sort the dictonary, we can convert the dictionary to a list of tuples and then sort the list based on keys or values.

# %% [markdown]
# ## Tuples

# %% [markdown]
# What is the major difference between tuples and lists?<br><br>
# The major difference between tuples and lists is that tuples are immutable, while lists are mutable. Additionally, tuples are defined using parentheses ( ) and lists are defined using square brackets [ ].

# %% [markdown]
# How do you create a tuple?<br><br>
# We can create a tuple by enclosing comma-separated values within parentheses '( )'.

# %% [markdown]
# ## Sets

# %% [markdown]
# What is unique about a set?<br><br>
# A set is a collection of unique elements where each element is unique within the set, meaning no duplicate values are allowed. Sets are unordered collections, meaning the elements are not stored in any specific order.

# %% [markdown]
# Use a set to find the unique values of the list below:

# %%
list5 = [1,2,2,33,4,4,11,22,3,3,2]
l5 = set(list5)
l5
# Out:
# {1, 2, 3, 4, 11, 22, 33}

# %% [markdown]
# ## Booleans

# %% [markdown]
# What will be the resulting Boolean of the following pieces of code (answer fist then check by typing it in!)

# %%
# What the outcome?
a = 2 > 3
a
#output is false
# Out:
# False
